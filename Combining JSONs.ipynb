# %%
import json
import pandas as pd

# %% [markdown]
# ## COVID Population Data

# %%
# Opening JSON file 
f = open('state_pop.json',) 
# returns JSON object as  
# a dictionary 
data = json.load(f)

# %%
#data

# %%
state_population=[]
# Iterating through the json 
# list 
for i in data: 
    #print(i)
    state_population.append(i)

# %% [markdown]
# ## COVID STATE DATA

# %%
# Opening JSON file 
f = open('nyt_covid_states.json',)
# returns JSON object as  
# a dictionary 
data = json.load(f)

# %%
state_COVID=[]
# Iterating through the json 
# list 
for i in data: 
    #print(i)
    state_COVID.append(i)

# %%
# Closing file 
f.close()

# %%
state_pop_df=pd.DataFrame(state_population)
state_pop_df.head(5)
# Out:
#         State  Population State_FIPS   Latitude   Longitude
# 0     Alabama   4850771.0         01  32.318231  -86.902298
# 1      Alaska    738565.0         02  64.200841 -149.493673
# 2     Arizona   6809946.0         04  34.048928 -111.093731
# 3    Arkansas   2977944.0         05  35.201050  -91.831833
# 4  California  38982847.0         06  36.778261 -119.417932

# %%
state_COVID_df=pd.DataFrame(state_COVID)
state_COVID_df.head(20)
# Out:
#        date                 state  fips   cases  deaths  confirmed_cases  \
# 0   7/29/20               Alabama     1   83782    1538          81572.0
# 1   7/29/20                Alaska     2    3440      20           3440.0
# 2   7/29/20               Arizona     4  168293    3466              NaN
# 3   7/29/20              Arkansas     5   40968     434          40968.0
# 4   7/29/20            California     6  482578    8789         482578.0
# 5   7/29/20              Colorado     8   45420    1809              NaN
# 6   7/29/20           Connecticut     9   49540    4425              NaN
# 7   7/29/20              Delaware    10   14602     581              NaN
# 8   7/29/20  District of Columbia    11   11999     584          11999.0
# 9   7/29/20               Florida    12  451415    6332              0.0
# 10  7/29/20               Georgia    13  163547    3566         163547.0
# 11  7/29/20                  Guam    66    1320       6           1312.0
# ...
