# %%
import pandas as pd
import numpy as np
import flask
import pymongo
import json
from datetime import datetime

# %%
covid_data = 'july-31-dc-covid.csv'

# %%
dc_covid_df = pd.read_csv(covid_data)

# %%
dc_covid_df = dc_covid_df.sort_values('Date', ascending = False)

# %%
dc_covid_df
# Out:
#                                   Date  3/7/20  3/8/20  3/9/20  3/10/20  \
# 2                      Total Positives     2.0     2.0     4.0      4.0
# 0                 Total Overall Tested     NaN     NaN     NaN      NaN
# 1  Total Number of DC Residents Tested     NaN     NaN     NaN      NaN
# 3                     Number of Deaths     NaN     NaN     NaN      NaN
# 4               Cleared From Isolation     NaN     NaN     NaN      NaN
#
#    3/11/20  3/12/20  3/13/20  3/14/20  3/15/20  ...  7/22/20  7/23/20  \
# 2     10.0     10.0     10.0     16.0     17.0  ...    11571    11649
# 0      NaN      NaN     69.0    115.0    120.0  ...   162021   165260
# 1      NaN      NaN      NaN      NaN      NaN  ...   115353   115353
# 3      NaN      NaN      0.0      0.0      0.0  ...      581      581
# 4      NaN      NaN      NaN      NaN      NaN  ...     2020     9582
#
#    7/24/20  7/25/20  7/26/20  7/27/20  7/28/20  7/29/20  7/30/20  7/31/20
# ...

# %%
json_dc_covid = dc_covid_df.to_json(orient = 'records')
parsed = json.loads(json_dc_covid)
print(json.dumps(parsed, indent = 4, sort_keys= True))
# Out:
# [
#     {
#         "3/10/20": 4.0,
#         "3/11/20": 10.0,
#         "3/12/20": 10.0,
#         "3/13/20": 10.0,
#         "3/14/20": 16.0,
#         "3/15/20": 17.0,
#         "3/16/20": 22.0,
#         "3/17/20": 31.0,
#         "3/18/20": 39.0,
#         "3/19/20": 71.0,
#         "3/20/20": 77.0,
#         "3/21/20": 98.0,
#         "3/22/20": 116.0,
#         "3/23/20": 137.0,
#         "3/24/20": 183.0,
#         "3/25/20": 231.0,
#         "3/26/20": 267.0,
#         "3/27/20": 304.0,
#         "3/28/20": 342.0,
#         "3/29/20": 401.0,
#         "3/30/20": 495.0,
#         "3/31/20": 586.0,
#         "3/7/20": 2.0,
#         "3/8/20": 2.0,
#         "3/9/20": 4.0,
#         "4/1/20": 653.0,
#         "4/10/20": 1778.0,
#         "4/11/20": 1875.0,
#         "4/12/20": 1955.0,
#         "4/13/20": "2,058",
#         "4/14/20": 2197.0,
#         "4/15/20": 2350.0,
#         "4/16/20": 2476.0,
#         "4/17/20": 2666.0,
#         "4/18/20": 2793.0,
# ...

# %%
with open('dc_covid_july31.json', 'w') as f:
    json.dump(parsed, f, indent=4)
